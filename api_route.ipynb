# %%
import requests 

description = {
    "description_text" : "I had to pay twice for my order, i want my refund."
}
response = requests.post("http://127.0.0.1:5000/get_category", json=description)
print(response.text)
# Out:
# {
#   "model_prediction": "billing",
#   "model_probability": "34.19%",
#   "status": "success"
# }

# %%
priority = {
    "complaint_category" : "packaging",
    "complaint_description" : "The product arrivied but the packaging is so bad it has started dripping",
    "complaint_product" : "Cleanser",
    "communication_channel" : "Email"
}

priority_response = requests.post("http://127.0.0.1:5000/get_priority", json=priority)
print(priority_response.text)
# Out:
# {
#   "predicted_priority": 3,
#   "priority_proba": 38.53,
#   "status": "success"
# }
